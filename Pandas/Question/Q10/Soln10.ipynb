# %% [markdown]
# ### Dataframe Append
# #### Description
# #### Append two datasets df_1 and df_2, and print the combined dataframe.

# %%
import pandas as pd

# %%
df_1=pd.read_csv("restaurant-1.csv")
df_2=pd.read_csv("restaurant-2.csv")

# %%
print(df_1.shape)
df_1.head(3)
# Out:
# (112, 5)
#                         name                     address            city  \
# 0  arnie morton's of chicago   "435 s. la cienega blvd."   "los angeles"
# 1                 art's deli       "12224 ventura blvd."   "studio city"
# 2              bel-air hotel      "701 stone canyon rd."       "bel air"
#
#           cuisine unique_id
# 0   "steakhouses"       '0'
# 1         "delis"       '1'
# 2   "californian"       '2'

# %%
print(df_2.shape)
df_2.head(3)
# Out:
# (752, 5)
#                       name_2                  address_2          city_2  \
# 0  arnie morton's of chicago   "435 s. la cienega blv."   "los angeles"
# 1         art's delicatessen      "12224 ventura blvd."   "studio city"
# 2              hotel bel-air     "701 stone canyon rd."       "bel air"
#
#         cuisine_2 unique_id
# 0      "american"       '0'
# 1      "american"       '1'
# 2   "californian"       '2'

# %%
#As we can see that columns are same 5...So, it can be appended at the axis=0(Row Wise) so, it as an type of merging.
df_1.append(df_2)
# Out:
#                           name                     address             city  \
# 0    arnie morton's of chicago   "435 s. la cienega blvd."    "los angeles"
# 1                   art's deli       "12224 ventura blvd."    "studio city"
# 2                bel-air hotel      "701 stone canyon rd."        "bel air"
# 3                   cafe bizou       "14016 ventura blvd."   "sherman oaks"
# 4                    campanile       "624 s. la brea ave."    "los angeles"
# ..                         ...                         ...              ...
# 747                        NaN                         NaN              NaN
# 748                        NaN                         NaN              NaN
# 749                        NaN                         NaN              NaN
# 750                        NaN                         NaN              NaN
# 751                        NaN                         NaN              NaN
#
# ...
